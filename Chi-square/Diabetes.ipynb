# %% [markdown]
# Find relation of age with diabetes outcome
#
# Group age into 3 categories:
#
# - Young <= 30
# - Middle 30-50
# - Old >50

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# %%
df = pd.read_csv('diabetes.csv')

# %%
groups = [group['Outcome'] for level, group in df.groupby('Age')]

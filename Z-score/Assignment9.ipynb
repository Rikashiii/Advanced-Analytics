# %% [markdown]
# 1. Calculate Z-scores and do outlier analysis on
#
# 	- Glucose column of Diabetes dataset
# 	- Billionaires dataset

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats

# %%
df = pd.read_csv('diabetes.csv')

# %%
#Calculate z-scores for Glucose column
z_scores = stats.zscore(df['Glucose'])
df['Z-score'] = z_scores
df['Z-score']
# Out:
# 0      0.848324
# 1     -1.123396
# 2      1.943724
# 3     -0.998208
# 4      0.504055
#          ...
# 763   -0.622642
# 764    0.034598
# 765    0.003301
# 766    0.159787
# 767   -0.873019
# Name: Z-score, Length: 768, dtype: float64

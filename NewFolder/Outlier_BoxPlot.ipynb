# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
#     BoxPlot is also called Whishker's Plot

# %%
commuter_times = [16, 8, 35, 17, 13, 15, 15, 5, 16, 25, 20, 20, 12, 10]
data_array = np.array(commuter_times)

q1 = np.percentile(data_array, 25)  # 25th percentile = Q1
q3 = np.percentile(data_array, 75)  # 75th percentile = Q3
iqr = q3 - q1
lower_fence = q1 - 1.5 * iqr
upper_fence = q3 + 1.5 * iqr
outliers = data_array[(data_array < lower_fence) | (data_array > upper_fence)]

print(f"Q1: {q1}")
print(f"Q2: {np.median(data_array)}")
print(f"Q3: {q3}")
print(f"IQR: {iqr}")
print(f"Lower Fence: {lower_fence}")
print(f"Upper Fence: {upper_fence}")
print(f"Outliers: {outliers}")
# Out:
# Q1: 12.25
# Q2: 15.5
# Q3: 19.25
# IQR: 7.0
# Lower Fence: 1.75
# Upper Fence: 29.75
# Outliers: [35]

# %%
#create box plot
plt.figure(figsize=(10,6))
sns.boxplot(data=commuter_times,orient='v')
plt.title('Box Plot of Commuter times')
plt.xlabel('Minutes')
plt.show()

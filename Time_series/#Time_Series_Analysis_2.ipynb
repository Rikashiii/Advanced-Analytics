# %% [markdown]
# # MS: Month Start frquency

# %% [markdown]
# create a data frame to hold index values from 01.01.61 to 01.12.62

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
airP = sns.load_dataset('flights')

# %%
futureDate = pd.DataFrame(pd.date_range(start='1961-01-01', end='1962-12-01'), columns=['Dates'])
futureDate.set_index('Dates', inplace=True)
print(futureDate.head())
# Out:
# Empty DataFrame
# Columns: []
# Index: [1961-01-01 00:00:00, 1961-01-02 00:00:00, 1961-01-03 00:00:00, 1961-01-04 00:00:00, 1961-01-05 00:00:00]

# %%
#Predict and print
print(model_fit.predict(start=futureDate.index[0], end=futureDate.index[-1]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 #Predict and print
# ----> 2 print(model_fit.predict(start=futureDate.index[0], end=futureDate.index[-1]))
#
# NameError: name 'model_fit' is not defined

# %%
#Plot
airP.dropna()
sns.lineplot(data=airP, x=airP.index, y='passengers')
sns.lineplot(data=airP, x=airP.index, y='sarimaxPred')
sns.lineplot(data=airP, x=airP.index, y='arimaPred2')
model_fit.predict(start=futureDate.index[0], end=futureDate.index[-1].plot(color='black'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 4
#       2 airP.dropna()
#       3 sns.lineplot(data=airP, x=airP.index, y='passengers')
# ----> 4 sns.lineplot(data=airP, x=airP.index, y='sarimaxPred')
#       5 sns.lineplot(data=airP, x=airP.index, y='arimaPred2')
#       6 model_fit.predict(start=futureDate.index[0], end=futureDate.index[-1].plot(color='black'))
#
# File ~\AppData\Roaming\Python\Python313\site-packages\seaborn\relational.py:485, in lineplot(data, x, y, hue, size, style, units, weights, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     471 def lineplot(
#     472     data=None, *,
#     473     x=None, y=None, hue=None, size=None, style=None, units=None, weights=None,
#    (...)    481
# ...

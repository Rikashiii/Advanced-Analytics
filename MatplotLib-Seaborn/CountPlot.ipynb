# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('tips.csv')

# %% [markdown]
# Count Plot :
#
#     Used to find the Count (Duh!)

# %%
# plt.Figure(figsize=(6,4))
# #divide 'total_bill' into 10 different categories, try changing bins
# plt.boxplot(df['total_bill'],df['tip'],color='orange',edgecolor='black')
# plt.title('Tip by Gender')
# plt.xlabel('Gender')
# plt.ylabel('Tip')
# plt.show()

# %% [markdown]
# Boxplot of tip by gender using sns
#
#     Useful for identifying 'outliers' {LAB_EXAM?}

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='smoker',data=df, hue='smoker', palette='Set2', legend=True)
plt.title('Count of Smokers Vs Non-Smokers')
plt.show()
